# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sett_types = pd.read_csv("../../data/hun/HU_places_admin_pop_ZIP_latlon.csv",
           sep=',',
           header=0)
KSH = pd.read_csv("../../data/hun/KSHCommuting_c1ID_c1name_c2ID_c2name_comm_school_work_DIR.csv",
           sep=',',
           header=0)

# %%
KSH
# Out:
#         origID    origName  destID           destName  CommutersAll  \
# 0         1508   Ipolyszög    1508          Ipolyszög            40
# 1         1508   Ipolyszög    3115        Dunaújváros             2
# 2         1508   Ipolyszög    3179  Budapest 02. ker.             2
# 3         1508   Ipolyszög    3249            Õrhalom             2
# 4         1508   Ipolyszög    4507         Szendehely             4
# ...        ...         ...     ...                ...           ...
# 114040   34412  Mosonudvar   28149       Mosonszolnok            19
# 114041   34412  Mosonudvar   29221       Jánossomorja             5
# 114042   34412  Mosonudvar   31839           Újrónafõ             2
# 114043   34412  Mosonudvar   34412         Mosonudvar            52
# 114044   34412  Mosonudvar   40401           Ausztria             6
#
#         CommutersSchool  CommutersWork
# 0                     0             40
# 1                     0              2
# 2                     0              2
# 3                     0              2
# 4                     0              4
# ...                 ...            ...
# 114040                0             19
# 114041                0              5
# 114042                0              2
# 114043                0             52
# 114044                0              6
#
# [114045 rows x 7 columns]

# %%
sett_types
# Out:
#            place  KSH code settlement type            admin county  \
# 0            Aba     17376      nagyközség                   Fejér
# 1     Abádszalók     12441           város    Jász-Nagykun-Szolnok
# 2       Abaliget     12548          község                 Baranya
# 3         Abasár     24554          község                   Heves
# 4     Abaújalpár     15662          község    Borsod-Abaúj-Zemplén
# ...          ...       ...             ...                     ...
# 3172     Zsennye     12292          község                     Vas
# 3173       Zsira      4622          község       Győr-Moson-Sopron
# 3174      Zsombó     17765          község                Csongrád
# 3175      Zsujta     11022          község    Borsod-Abaúj-Zemplén
# 3176       Zsurk     13037          község  Szabolcs-Szatmár-Bereg
#
#      admin municip  population   zip  latitude  longitude
# 0              Aba        4619  8127   47.0291    18.5217
# 1       Tiszafüred        3922  5241   47.4667    20.6000
# 2             Pécs         586  7678   46.1426    18.1168
# 3         Gyöngyös        2498  3261   47.7970    20.0032
# 4             Encs          76  3882   48.3067    21.2332
# ...            ...         ...   ...       ...        ...
# 3172   Szombathely         100  9766   47.1130    16.8152
# 3173        Sopron         782  9476   47.4576    16.6773
# 3174        Szeged        3552  6792   46.3257    19.9746
# 3175          Gönc         164  3897   48.5000    21.2833
# 3176        Záhony         704  4627   48.4118    22.2195
#
# [3177 rows x 9 columns]

# %%
len(set(KSH["origName"]))
print(set(sett_types["settlement type"]))
sett_types.groupby("settlement type").size().sort_values(ascending=False)
# Out:
# {'megyeszékhely-megyei jogú város', 'város', 'nagyközség', 'fővárosi kerület', 'főváros', 'megyei jogú város', 'község'}
# settlement type
# község                             2706
# város                               304
# nagyközség                          120
# fővárosi kerület                     23
# megyeszékhely-megyei jogú város      18
# megyei jogú város                     5
# főváros                               1
# dtype: int64

# %%
sett_types[sett_types["population"]>=5000]
# Out:
#               place  KSH code                  settlement type  \
# 12            Abony     27872                            város
# 14              Ács      4428                            város
# 31             Ajka      6673                            város
# 37       Albertirsa     31653                            város
# 40            Algyő     34245                       nagyközség
# ...             ...       ...                              ...
# 3061         Vésztő     29531                            város
# 3111   Zalaegerszeg     32054  megyeszékhely-megyei jogú város
# 3129  Zalaszentgrót     32522                            város
# 3157           Zirc     26499                            város
# 3163        Zsámbék     25034                            város
#
#            admin county  admin municip  population   zip  latitude  longitude
# 12                 Pest         Cegléd       14876  2740   47.1899    20.0048
# 14    Komárom-Esztergom        Komárom        6965  2941   47.7123    18.0113
# 31             Veszprém           Ajka       29058  8400   47.1020    17.5589
# 37                 Pest         Cegléd       12410  2730   47.2431    19.6169
# 40             Csongrád         Szeged        5251  6750   46.3347    20.2085
# ...                 ...            ...         ...   ...       ...        ...
# 3061              Békés      Szeghalom        6680  5530   46.9167    21.2667
# 3111               Zala   Zalaegerszeg       61849  8900   46.8400    16.8439
# 3129               Zala  Zalaszentgrót        6473  8785   46.9447    17.0793
# 3157           Veszprém           Zirc        7096  8420   47.2636    17.8737
# 3163               Pest  Pilisvörösvár        5480  2072   47.5481    18.7201
#
# [295 rows x 9 columns]

# %%
korfa_teltip0 = {
    "főváros|fővárosi kerület": [210640, 81626, 246127, 313540, 213367, 225379, 216828, 221533, 1729040],
    "megyeszékhely-megyei jogú város": [238608 , 116868 , 233585 , 287108 , 227042 , 252073 , 209260 , 197113 , 1761657],
    "megyei jogú város": [37141, 15599, 32610, 44865, 35886, 39168, 32719, 29748, 267736],
    "város": [477932, 195704, 364021, 491615, 422355, 466796, 373198, 353804, 3145425],
    "all_város": [964321, 409797, 876343, 1137128, 898650, 983416, 832005, 802198, 6903858],
    "község|nagyközség": [483338, 183737, 353193, 443785, 417543, 455266, 344957, 351951, 3033770],
    "all": [1447659 , 593534 , 1229536 , 1580913 , 1316193 , 1438682 , 1176962 , 1154149 , 9937628],
}

sum(korfa_teltip0["főváros|fővárosi kerület"]), sum(korfa_teltip0["megyeszékhely-megyei jogú város"]), sum(korfa_teltip0["község|nagyközség"]),
# Out:
# (3458080, 3523314, 6067540)

# %%
korfa_teltip0 = {
    "főváros|fővárosi kerület": [210640, 81626, 246127, 313540, 213367, 225379, 216828, 221533, 1729040],
    "megyeszékhely-megyei jogú város": [238608 , 116868 , 233585 , 287108 , 227042 , 252073 , 209260 , 197113 , 1761657],
    "megyei jogú város": [37141, 15599, 32610, 44865, 35886, 39168, 32719, 29748, 267736],
    "város": [477932, 195704, 364021, 491615, 422355, 466796, 373198, 353804, 3145425],
    "all_város": [964321, 409797, 876343, 1137128, 898650, 983416, 832005, 802198, 6903858],
    "község|nagyközség": [483338, 183737, 353193, 443785, 417543, 455266, 344957, 351951, 3033770],
    "all": [1447659 , 593534 , 1229536 , 1580913 , 1316193 , 1438682 , 1176962 , 1154149 , 9937628],
}

korfa_teltip1 = {
    "főváros": [210640, 81626, 246127, 313540, 213367, 225379, 216828, 221533, 1729040],
    "fővárosi kerület": [210640, 81626, 246127, 313540, 213367, 225379, 216828, 221533, 1729040],
    "megyeszékhely-megyei jogú város": [238608 , 116868 , 233585 , 287108 , 227042 , 252073 , 209260 , 197113 , 1761657],
    "megyei jogú város": [37141, 15599, 32610, 44865, 35886, 39168, 32719, 29748, 267736],
    "város": [477932, 195704, 364021, 491615, 422355, 466796, 373198, 353804, 3145425],
    "all_város": [964321, 409797, 876343, 1137128, 898650, 983416, 832005, 802198, 6903858],
    "község": [483338, 183737, 353193, 443785, 417543, 455266, 344957, 351951, 3033770],
    "nagyközség": [483338, 183737, 353193, 443785, 417543, 455266, 344957, 351951, 3033770],
    "all": [1447659 , 593534 , 1229536 , 1580913 , 1316193 , 1438682 , 1176962 , 1154149 , 9937628],
}
ages = ["0–14", "15–19", "20–29", "30–39", "40–49", "50–59", "60–69", "70–", "all"]

# %%
fig,ax = plt.subplots(1,1,figsize=(12,10))
x = np.array(range(8))
for i, (teltip, arr) in enumerate(korfa_teltip0.items()):
    plt.bar(x-(i-2)*0.1, arr[:-1]/np.sum(arr[:-1]), label=teltip, alpha=0.5, width=0.1)
    
ax.set_xticks(x)
ax.set_xticklabels(ages[:-1], rotation=65)
plt.legend()

# %% [markdown]
# # Create population.json

# %%
def get_age(row, korfa_teltip, I, L):
    arr = np.array(korfa_teltip[row["settlement type"]])
    arr = arr[:-1]/np.sum(arr[:-1])
    N = row["population"]
    
    # [age15/3, age15/3, age15/3, ..., age70+]
    ages = [arr[0]/3, arr[0]/3, arr[0]/3, arr[]]
    for ratio in arr[1:-1]:
        ages += [ratio/2, ratio/2]
    ages += [ratio]
    ages = np.array([int(a*N) for a in ages])
    
    Is = np.random.multinomial(I, ages/np.sum(ages))
    Ls = np.random.multinomial(L, ages/np.sum(ages))
    
    ages = [{"N": int(s), "S":int(s-i-l), "L":int(l), "I":int(i), "R":0} for s,l,i in zip(ages,Ls,Is)]
    return ages

def create_population_dict(sett_types, population_th, num_I, num_L):
    small_cities = sett_types[sett_types["population"]>population_th]
    pop = np.array(list(small_cities["population"].array))
    
    Is = np.random.multinomial(num_I, pop/np.sum(pop))
    Ls = np.random.multinomial(num_L, pop/np.sum(pop))
    
    
    place_id_dict = {}
    population = {"populations":[]}
    Sum = 0
    for ind, (_, row) in enumerate(small_cities.iterrows()):
        place_id_dict[row['place']] = ind
        city = {
            "name": str(ind),
            #"name": row["place"],
            "index": ind,
            "N": row["population"],
            "r1":0.75,
            "r2":0.15,
            "age": get_age(row, korfa_teltip1, Is[ind], Ls[ind])
        }
        population["populations"].append(city)
        Sum+=Is[ind]
        ind += 1
    return population, set(small_cities['place']), place_id_dict

# %%
pops,cities,place_id_dict = create_population_dict(
    sett_types, population_th=10000,
    num_I =10000,
    num_L=int(10000*(4/2.5)))

with open("../input/hun/populations_KSH.json", "w") as f:
    f.write(json.dumps(pops))

# %%
print(f"Number of cities: {len(cities)}")
print(f'Number of age groups {len(pops["populations"][1]["age"])}')
N = len(cities)
pops["populations"][2]
# Out:
# Number of cities: 168
# Number of age groups 16
# {'name': '2',
#  'index': 2,
#  'N': 12410,
#  'r1': 0.75,
#  'r2': 0.15,
#  'age': [{'N': 628, 'S': 625, 'L': 3, 'I': 0, 'R': 0},
#   {'N': 628, 'S': 626, 'L': 1, 'I': 1, 'R': 0},
#   {'N': 628, 'S': 628, 'L': 0, 'I': 0, 'R': 0},
#   {'N': 386, 'S': 384, 'L': 1, 'I': 1, 'R': 0},
#   {'N': 386, 'S': 385, 'L': 1, 'I': 0, 'R': 0},
#   {'N': 718, 'S': 717, 'L': 1, 'I': 0, 'R': 0},
#   {'N': 718, 'S': 717, 'L': 1, 'I': 0, 'R': 0},
#   {'N': 969, 'S': 964, 'L': 1, 'I': 4, 'R': 0},
#   {'N': 969, 'S': 966, 'L': 2, 'I': 1, 'R': 0},
#   {'N': 833, 'S': 831, 'L': 1, 'I': 1, 'R': 0},
#   {'N': 833, 'S': 830, 'L': 1, 'I': 2, 'R': 0},
#   {'N': 920, 'S': 917, 'L': 2, 'I': 1, 'R': 0},
#   {'N': 920, 'S': 919, 'L': 1, 'I': 0, 'R': 0},
#   {'N': 736, 'S': 732, 'L': 2, 'I': 2, 'R': 0},
#   {'N': 736, 'S': 734, 'L': 0, 'I': 2, 'R': 0},
#   {'N': 1472, 'S': 1463, 'L': 7, 'I': 2, 'R': 0}]}

# %%
print(f"Number of cities: {len(cities)}")
print(f'Number of age groups {len(pops["populations"][1]["age"])}')
N = len(cities)
pops["populations"][2]
# Out:
# Number of cities: 168
# Number of age groups 16
# {'name': '2',
#  'index': 2,
#  'N': 12410,
#  'r1': 0.75,
#  'r2': 0.15,
#  'age': [{'N': 628, 'S': 626, 'L': 2, 'I': 0, 'R': 0},
#   {'N': 628, 'S': 626, 'L': 1, 'I': 1, 'R': 0},
#   {'N': 628, 'S': 624, 'L': 1, 'I': 3, 'R': 0},
#   {'N': 386, 'S': 385, 'L': 1, 'I': 0, 'R': 0},
#   {'N': 386, 'S': 385, 'L': 1, 'I': 0, 'R': 0},
#   {'N': 718, 'S': 714, 'L': 3, 'I': 1, 'R': 0},
#   {'N': 718, 'S': 718, 'L': 0, 'I': 0, 'R': 0},
#   {'N': 969, 'S': 965, 'L': 1, 'I': 3, 'R': 0},
#   {'N': 969, 'S': 969, 'L': 0, 'I': 0, 'R': 0},
#   {'N': 833, 'S': 831, 'L': 1, 'I': 1, 'R': 0},
#   {'N': 833, 'S': 831, 'L': 1, 'I': 1, 'R': 0},
#   {'N': 920, 'S': 915, 'L': 4, 'I': 1, 'R': 0},
#   {'N': 920, 'S': 918, 'L': 2, 'I': 0, 'R': 0},
#   {'N': 736, 'S': 731, 'L': 4, 'I': 1, 'R': 0},
#   {'N': 736, 'S': 734, 'L': 1, 'I': 1, 'R': 0},
#   {'N': 1472, 'S': 1465, 'L': 6, 'I': 1, 'R': 0}]}

# %%
# Check the number of infected agents
Sum_L = 0
Sum_I = 0
Sum_All = 0
for i in range(len(cities)):
    Sum_L += sum([age['L'] for age in pops["populations"][i]['age']])
    Sum_I += sum([age['I'] for age in pops["populations"][i]['age']])
    Sum_All += sum([age['N'] for age in pops["populations"][i]['age']])
print(Sum_L,Sum_I, Sum_All)
# Out:
# 16000 10000 7735924

# %%
pop_dict = {row['place']:row["population"] for _,row in sett_types.iterrows()}

# %%
pop_dict
# Out:
# {'Aba': 4619,
#  'Abádszalók': 3922,
#  'Abaliget': 586,
#  'Abasár': 2498,
#  'Abaújalpár': 76,
#  'Abaújkér': 667,
#  'Abaújlak': 131,
#  'Abaújszántó': 3088,
#  'Abaújszolnok': 191,
#  'Abaújvár': 206,
#  'Abda': 3201,
#  'Abod': 229,
#  'Abony': 14876,
#  'Ábrahámhegy': 445,
#  'Ács': 6965,
#  'Acsa': 1443,
#  'Acsád': 672,
#  'Acsalag': 452,
#  'Ácsteszér': 666,
#  'Adács': 2690,
#  'Ádánd': 2199,
#  'Adásztevel': 771,
#  'Adony': 3912,
#  'Adorjánháza': 338,
#  'Adorjás': 181,
#  'Ág': 179,
#  'Ágasegyháza': 2018,
#  'Ágfalva': 2178,
#  'Aggtelek': 535,
#  'Agyagosszergény': 882,
#  'Ajak': 3528,
#  'Ajka': 29058,
#  'Aka': 278,
#  'Akasztó': 3230,
#  'Alacska': 748,
#  'Alap': 1925,
#  'Alattyán': 2101,
#  'Albertirsa': 12410,
#  'Alcsútdoboz': 1446,
#  'Aldebrő': 649,
#  'Algyő': 5251,
#  'Alibánfa': 453,
#  'Almamellék': 428,
#  'Almásfüzitő': 2174,
#  'Almásháza': 69,
#  'Almáskamarás': 835,
#  'Almáskeresztúr': 83,
#  'Álmosd': 1555,
#  'Alsóberecki': 722,
#  'Alsóbogát': 258,
#  'Alsódobsza': 319,
#  'Alsógagy': 97,
#  'Alsómocsolád': 329,
#  'Alsónána': 689,
#  'Alsónémedi': 5206,
#  'Alsónemesapáti': 722,
#  'Alsónyék': 751,
#  'Alsóörs': 1474,
#  'Alsópáhok': 1293,
#  'Alsópetény': 666,
#  'Alsórajk': 347,
#  'Alsóregmec': 196,
#  'Alsószenterzsébet': 66,
#  'Alsószentiván': 608,
#  'Alsószentmárton': 1177,
#  'Alsószölnök': 367,
#  'Alsószuha': 479,
#  'Alsótelekes': 135,
#  'Alsótold': 243,
#  'Alsóújlak': 584,
#  'Alsóvadász': 1562,
#  'Alsózsolca': 5937,
#  'Ambrózfalva': 486,
#  'Anarcs': 1912,
#  'Andocs': 1094,
#  'Andornaktálya': 2740,
#  'Andrásfa': 246,
#  'Annavölgy': 935,
#  'Apácatorna': 163,
#  'Apagy': 2199,
#  'Apaj': 1205,
#  'Aparhant': 1006,
#  'Apátfalva': 2941,
#  'Apátistvánfalva': 358,
#  'Apátvarasd': 134,
#  'Apc': 2552,
#  'Áporka': 1182,
#  'Apostag': 1948,
#  'Aranyosapáti': 1979,
#  'Aranyosgadány': 321,
#  'Arka': 73,
#  'Arló': 3686,
#  'Arnót': 2544,
#  'Ároktő': 1051,
#  'Árpádhalom': 488,
#  'Árpás': 245,
#  'Ártánd': 502,
#  'Ásotthalom': 3986,
#  'Ásványráró': 1858,
#  'Aszaló': 1879,
#  'Ászár': 1964,
#  'Aszód': 6414,
#  'Aszófő': 401,
#  'Áta': 168,
#  'Átány': 1351,
#  'Atkár': 1695,
#  'Attala': 830,
#  'Babarc': 729,
#  'Babarcszőlős': 96,
#  'Babócsa': 1532,
#  'Bábolna': 3654,
#  'Bábonymegyer': 809,
#  'Babosdöbréte': 498,
#  'Babót': 1097,
#  'Bácsalmás': 6697,
#  'Bácsbokod': 2619,
#  'Bácsborsód': 1196,
#  'Bácsszentgyörgy': 156,
#  'Bácsszőlős': 359,
#  'Badacsonytomaj': 2080,
#  'Badacsonytördemic': 820,
#  'Bag': 3883,
#  'Bagamér': 2478,
#  'Baglad': 45,
#  'Bagod': 1329,
#  'Bágyogszovát': 1284,
#  'Baj': 2870,
#  'Baja': 37330,
#  'Bajánsenye': 455,
#  'Bajna': 1896,
#  'Bajót': 1557,
#  'Bak': 1665,
#  'Bakháza': 180,
#  'Bakóca': 275,
#  'Bakonszeg': 1160,
#  'Bakonya': 379,
#  'Bakonybánk': 424,
#  'Bakonybél': 1193,
#  'Bakonycsernye': 3097,
#  'Bakonygyirót': 148,
#  'Bakonyjákó': 613,
#  'Bakonykoppány': 191,
#  'Bakonykúti': 134,
#  'Bakonynána': 1047,
#  'Bakonyoszlop': 507,
#  'Bakonypéterd': 279,
#  'Bakonypölöske': 371,
#  'Bakonyság': 46,
#  'Bakonysárkány': 941,
#  'Bakonyszentiván': 216,
#  'Bakonyszentkirály': 804,
#  'Bakonyszentlászló': 1703,
#  'Bakonyszombathely': 1421,
#  'Bakonyszücs': 319,
#  'Bakonytamási': 591,
#  'Baks': 1963,
#  'Baksa': 769,
#  'Baktakék': 718,
#  'Baktalórántháza': 4302,
#  'Baktüttös': 327,
#  'Balajt': 463,
#  'Balassagyarmat': 16133,
#  'Balástya': 3423,
#  'Balaton': 1038,
#  'Balatonakali': 627,
#  'Balatonalmádi': 9167,
#  'Balatonberény': 1156,
#  'Balatonboglár': 5932,
#  'Balatoncsicsó': 218,
#  'Balatonederics': 1013,
#  'Balatonendréd': 1339,
#  'Balatonfenyves': 1844,
#  'Balatonfőkajár': 1332,
#  'Balatonföldvár': 2064,
#  'Balatonfüred': 13532,
#  'Balatonfűzfő': 4299,
#  'Balatongyörök': 1113,
#  'Balatonhenye': 106,
#  'Balatonkenese': 3195,
#  'Balatonkeresztúr': 1450,
#  'Balatonlelle': 4735,
#  'Balatonmagyaród': 480,
#  'Balatonmáriafürdő': 657,
#  'Balatonőszöd': 508,
#  'Balatonrendes': 119,
#  'Balatonszabadi': 2956,
#  'Balatonszárszó': 1885,
#  'Balatonszemes': 1773,
#  'Balatonszentgyörgy': 1564,
#  'Balatonszepezd': 409,
#  'Balatonszőlős': 628,
#  'Balatonudvari': 314,
#  'Balatonújlak': 521,
#  'Balatonvilágos': 1179,
#  'Balinka': 945,
#  'Balkány': 6215,
#  'Ballószög': 3418,
#  'Balmazújváros': 17354,
#  'Balogunyom': 1190,
#  'Balotaszállás': 1497,
#  'Balsa': 841,
#  'Bálványos': 529,
#  'Bana': 1589,
#  'Bánd': 673,
#  'Bánfa': 187,
#  'Bánhorváti': 1335,
#  'Bánk': 662,
#  'Bánokszentgyörgy': 642,
#  'Bánréve': 1271,
#  'Bár': 534,
#  'Barabás': 746,
#  'Baracs': 3484,
#  'Baracska': 2766,
#  'Báránd': 2530,
#  'Baranyahídvég': 202,
#  'Baranyajenő': 489,
#  'Baranyaszentgyörgy': 121,
#  'Barbacs': 716,
#  'Barcs': 11378,
#  'Bárdudvarnok': 1202,
#  'Barlahida': 124,
#  'Bárna': 1053,
#  'Barnag': 116,
#  'Bársonyos': 738,
#  'Basal': 202,
#  'Baskó': 183,
#  'Báta': 1692,
#  'Bátaapáti': 396,
#  'Bátaszék': 6388,
#  'Baté': 832,
#  'Bátmonostor': 1504,
#  'Bátonyterenye': 12604,
#  'Bátor': 407,
#  'Bátorliget': 643,
#  'Battonya': 5565,
#  'Bátya': 2023,
#  'Batyk': 393,
#  'Bázakerettye': 826,
#  'Bazsi': 388,
#  'Béb': 254,
#  'Becsehely': 2066,
#  'Becske': 518,
#  'Becskeháza': 44,
#  'Becsvölgye': 768,
#  'Bedegkér': 463,
#  'Bedő': 252,
#  'Bejcgyertyános': 453,
#  'Békás': 231,
#  'Bekecs': 2391,
#  'Békés': 19763,
#  'Békéscsaba': 63752,
#  'Békéssámson': 2318,
#  'Békésszentandrás': 3765,
#  'Bekölce': 637,
#  'Bélapátfalva': 2996,
#  'Bélavár': 342,
#  'Belecska': 420,
#  'Beled': 2553,
#  'Beleg': 597,
#  'Belezna': 785,
#  'Bélmegyer': 981,
#  'Beloiannisz': 1100,
#  'Belsősárd': 99,
#  'Belvárdgyula': 402,
#  'Benk': 451,
#  'Bénye': 1221,
#  'Bér': 377,
#  'Bérbaltavár': 493,
#  'Bercel': 2111,
#  'Beregdaróc': 735,
#  'Beregsurány': 644,
#  'Berekböszörmény': 1749,
#  'Berekfürdő': 1010,
#  'Beremend': 2594,
#  'Berente': 1117,
#  'Beret': 272,
#  'Berettyóújfalu': 15167,
#  'Berhida': 5967,
#  'Berkenye': 637,
#  'Berkesd': 864,
#  'Berkesz': 908,
#  'Bernecebaráti': 848,
#  'Berzék': 1145,
#  'Berzence': 2502,
#  'Besence': 121,
#  'Besenyőd': 642,
#  'Besenyőtelek': 2569,
#  'Besenyszög': 3372,
#  'Besnyő': 1779,
#  'Beszterec': 980,
#  'Bezedek': 238,
#  'Bezenye': 1393,
#  'Bezeréd': 153,
#  'Bezi': 510,
#  'Biatorbágy': 12805,
#  'Bicsérd': 1008,
#  'Bicske': 11642,
#  'Bihardancsháza': 180,
#  'Biharkeresztes': 3888,
#  'Biharnagybajom': 2731,
#  'Bihartorda': 897,
#  'Biharugra': 839,
#  'Bikács': 433,
#  'Bikal': 743,
#  'Biri': 1376,
#  'Birján': 510,
#  'Bisse': 228,
#  'Boba': 807,
#  'Bocfölde': 1138,
#  'Boconád': 1248,
#  'Bócsa': 1830,
#  'Bocska': 342,
#  'Bocskaikert': 2946,
#  'Boda': 436,
#  'Bodajk': 4051,
#  'Bodmér': 222,
#  'Bodolyabér': 222,
#  'Bodonhely': 277,
#  'Bodony': 714,
#  'Bodorfa': 107,
#  'Bodrog': 430,
#  'Bodroghalom': 1303,
#  'Bodrogkeresztúr': 1107,
#  'Bodrogkisfalud': 836,
#  'Bodrogolaszi': 882,
#  'Bódvalenke': 184,
#  'Bódvarákó': 94,
#  'Bódvaszilas': 1005,
#  'Bogács': 2024,
#  'Bogád': 1094,
#  'Bogádmindszent': 431,
#  'Bogdása': 276,
#  'Bogyiszló': 2193,
#  'Bogyoszló': 598,
#  'Bojt': 489,
#  'Bókaháza': 305,
#  'Bokod': 2096,
#  'Bokor': 110,
#  'Boldog': 2975,
#  'Boldogasszonyfa': 426,
#  'Boldogkőújfalu': 544,
#  'Boldogkőváralja': 1084,
#  'Boldva': 2331,
#  'Bolhás': 407,
#  'Bolhó': 720,
#  'Bóly': 3996,
#  'Boncodfölde': 348,
#  'Bonyhád': 13741,
#  'Bonyhádvarasd': 402,
#  'Bonnya': 261,
#  'Bordány': 3262,
#  'Borgáta': 140,
#  'Borjád': 388,
#  'Borota': 1294,
#  'Borsfa': 710,
#  'Borsodbóta': 857,
#  'Borsodgeszt': 246,
#  'Borsodivánka': 739,
#  'Borsodnádasd': 3007,
#  'Borsodszentgyörgy': 1135,
#  'Borsodszirák': 1199,
#  'Borsosberény': 1001,
#  'Borszörcsök': 362,
#  'Borzavár': 712,
#  'Bosta': 135,
#  'Botpalád': 580,
#  'Botykapeterd': 312,
#  'Bozzai': 316,
#  'Bozsok': 328,
#  'Bózsva': 183,
#  'Bő': 640,
#  'Bőcs': 2754,
#  'Böde': 275,
#  'Bödeháza': 55,
#  'Bögöt': 382,
#  'Bögöte': 287,
#  'Böhönye': 2353,
#  'Bököny': 3168,
#  'Bölcske': 2825,
#  'Bőny': 2153,
#  'Börcs': 1290,
#  'Börzönce': 50,
#  'Bősárkány': 2111,
#  'Bőszénfa': 568,
#  'Bucsa': 2055,
#  'Bucsu': 586,
#  'Búcsúszentlászló': 819,
#  'Bucsuta': 227,
#  'Budajenő': 1877,
#  'Budakalász': 10510,
#  'Budakeszi': 14507,
#  'Budaörs': 29605,
#  'Budapest': 1740041,
#  'Budapest 01. ker.': 24528,
#  'Budapest 02. ker.': 88011,
#  'Budapest 03. ker.': 123889,
#  'Budapest 04. ker.': 99050,
#  'Budapest 05. ker.': 27342,
#  'Budapest 06. ker.': 43377,
#  'Budapest 07. ker.': 64767,
#  'Budapest 08. ker.': 85173,
#  'Budapest 09. ker.': 63697,
#  'Budapest 10. ker.': 81475,
#  'Budapest 11. ker.': 145510,
#  'Budapest 12. ker.': 55776,
#  'Budapest 13. ker.': 118320,
#  'Budapest 14. ker.': 123786,
#  'Budapest 15. ker.': 79779,
#  'Budapest 16. ker.': 68235,
#  'Budapest 17. ker.': 78537,
#  'Budapest 18. ker.': 94663,
#  'Budapest 19. ker.': 62210,
#  'Budapest 20. ker.': 63887,
#  'Budapest 21. ker.': 76976,
#  'Budapest 22. ker.': 51071,
#  'Budapest 23. ker.': 19982,
#  'Bugac': 2809,
#  'Bugacpusztaháza': 297,
#  'Bugyi': 5418,
#  'Buj': 2206,
#  'Buják': 2091,
#  'Buzsák': 1434,
#  'Bük': 3493,
#  'Bükkábrány': 1558,
#  'Bükkaranyos': 1467,
#  'Bükkmogyorósd': 119,
#  'Bükkösd': 1099,
#  'Bükkszék': 681,
#  'Bükkszenterzsébet': 1040,
#  'Bükkszentkereszt': 1212,
#  'Bükkszentmárton': 305,
#  'Bükkzsérc': 950,
#  'Bürüs': 97,
#  'Büssü': 340,
#  'Büttös': 167,
#  'Cák': 301,
#  'Cakóháza': 48,
#  'Cece': 2499,
#  'Cégénydányád': 668,
#  'Cegléd': 37778,
#  'Ceglédbercel': 4407,
#  'Celldömölk': 10786,
#  'Cered': 1060,
#  'Chernelházadamonya': 196,
#  'Cibakháza': 4327,
#  'Cigánd': 2682,
#  'Cikó': 821,
#  'Cirák': 568,
#  'Cún': 242,
#  'Csabacsűd': 1800,
#  'Csabaszabadi': 335,
#  'Csabdi': 1168,
#  'Csabrendek': 2969,
#  'Csáfordjánosfa': 209,
#  'Csaholc': 521,
#  'Csajág': 801,
#  'Csákány': 275,
#  'Csákánydoroszló': 1730,
#  'Csákberény': 1182,
#  'Csákvár': 5221,
#  'Csanádalberti': 434,
#  'Csanádapáca': 2617,
#  'Csanádpalota': 2968,
#  'Csánig': 372,
#  'Csány': 2204,
#  'Csányoszró': 668,
#  'Csanytelek': 2755,
#  'Csapi': 176,
#  'Csapod': 523,
#  'Csárdaszállás': 442,
#  'Csarnóta': 150,
#  'Csaroda': 568,
#  'Császár': 1750,
#  'Császártöltés': 2323,
#  'Császló': 367,
#  'Csátalja': 1468,
#  'Csatár': 561,
#  'Csataszög': 295,
#  'Csatka': 232,
#  'Csávoly': 1806,
#  'Csebény': 94,
#  'Csécse': 896,
#  'Csegöld': 592,
#  'Csehbánya': 273,
#  'Csehi': 245,
#  'Csehimindszent': 336,
#  'Csém': 447,
#  'Csemő': 4283,
#  'Csempeszkopács': 285,
#  'Csengele': 1967,
#  'Csenger': 4730,
#  'Csengersima': 692,
#  'Csengerújfalu': 777,
#  'Csengőd': 2020,
#  'Csénye': 724,
#  'Csenyéte': 438,
#  'Csép': 352,
#  'Csépa': 1535,
#  'Csepreg': 3384,
#  'Csér': 33,
#  'Cserdi': 375,
#  'Cserénfa': 188,
#  'Cserépfalu': 1002,
#  'Cserépváralja': 427,
#  'Cserháthaláp': 344,
#  'Cserhátsurány': 839,
#  'Cserhátszentiván': 139,
#  'Cserkeszőlő': 2090,
#  'Cserkút': 567,
#  'Csernely': 806,
#  'Cserszegtomaj': 2797,
#  'Csertalakos': 24,
#  'Csertő': 403,
#  'Csesznek': 515,
#  'Csesztreg': 790,
#  'Csesztve': 305,
#  'Csetény': 1880,
#  'Csévharaszt': 1941,
#  'Csibrák': 326,
#  'Csikéria': 889,
#  'Csikóstőttős': 873,
#  'Csikvánd': 454,
#  'Csincse': 562,
#  'Csipkerek': 322,
#  'Csitár': 385,
#  'Csobád': 692,
#  'Csobaj': 702,
#  'Csobánka': 3165,
#  'Csókakő': 1311,
#  'Csokonyavisonta': 1605,
#  'Csokvaomány': 843,
#  'Csolnok': 3253,
#  'Csólyospálos': 1658,
#  'Csoma': 437,
#  'Csomád': 1579,
#  'Csombárd': 287,
#  'Csongrád': 16846,
#  'Csonkahegyhát': 355,
#  'Csonkamindszent': 177,
#  'Csopak': 1648,
#  'Csór': 1832,
#  'Csorna': 10649,
#  'Csorvás': 4981,
#  'Csót': 968,
#  'Csöde': 78,
#  'Csögle': 621,
#  'Csökmő': 1756,
#  'Csököly': 1144,
#  'Csömend': 286,
#  'Csömödér': 580,
#  'Csömör': 9227,
#  'Csönge': 362,
#  'Csörnyeföld': 462,
#  'Csörög': 2296,
#  'Csörötnek': 843,
#  'Csősz': 1044,
#  'Csővár': 656,
#  'Csurgó': 5186,
#  'Csurgónagymarton': 172,
#  'Dabas': 16813,
#  'Dabronc': 406,
#  'Dabrony': 345,
#  'Dad': 1012,
#  'Dág': 938,
#  'Dáka': 643,
#  'Dalmand': 1264,
#  'Damak': 234,
#  'Dámóc': 397,
#  'Dánszentmiklós': 2996,
#  'Dány': 4524,
#  'Daraboshegy': 97,
#  'Darány': 905,
#  'Darnó': 167,
#  'Darnózseli': 1566,
#  'Daruszentmiklós': 1597,
#  'Darvas': 527,
#  'Dávod': 1926,
#  'Debercsény': 78,
#  'Debrecen': 207594,
#  'Debréte': 21,
#  'Decs': 4049,
#  'Dédestapolcsány': 1426,
#  'Dég': 2047,
#  'Dejtár': 1396,
#  'Délegyháza': 3575,
#  'Demecser': 4280,
#  'Demjén': 590,
#  'Dencsháza': 591,
#  'Dénesfa': 363,
#  'Derecske': 8906,
#  'Derekegyház': 1595,
#  'Deszk': 3644,
#  'Detek': 267,
#  'Detk': 1158,
#  'Dévaványa': 7622,
#  'Devecser': 4325,
#  'Dinnyeberki': 90,
#  'Diósberény': 353,
#  'Diósd': 9522,
#  'Diósjenő': 2784,
#  'Dióskál': 474,
#  'Diósviszló': 702,
#  'Doba': 512,
#  'Doboz': 4167,
#  'Dobri': 154,
#  'Dobronhegy': 137,
#  'Dóc': 765,
#  'Domaháza': 816,
#  'Domaszék': 4974,
#  'Dombegyház': 1943,
#  'Dombiratos': 526,
#  'Dombóvár': 19494,
#  'Dombrád': 3900,
#  'Domony': 2187,
#  'Domoszló': 1988,
#  'Dormánd': 1040,
#  'Dorog': 11996,
#  'Dorogháza': 1071,
#  'Dozmat': 226,
#  'Döbörhegy': 152,
#  'Döbröce': 72,
#  'Döbrököz': 1939,
#  'Döbrönte': 262,
#  'Döge': 2103,
#  'Dömös': 1157,
#  'Dömsöd': 5690,
#  'Dör': 693,
#  'Dörgicse': 249,
#  'Döröske': 75,
#  'Dötk': 27,
#  'Dövény': 283,
#  'Drágszél': 329,
#  'Drávacsehi': 214,
#  'Drávacsepely': 201,
#  'Drávafok': 503,
#  'Drávagárdony': 136,
#  'Drávaiványi': 196,
#  'Drávakeresztúr': 109,
#  'Drávapalkonya': 249,
#  'Drávapiski': 112,
#  'Drávaszabolcs': 703,
#  'Drávaszerdahely': 188,
#  'Drávasztára': 398,
#  'Drávatamási': 387,
#  'Drégelypalánk': 1493,
#  'Dubicsány': 285,
#  'Dudar': 1534,
#  'Duka': 218,
#  'Dunaalmás': 1633,
#  'Dunabogdány': 3255,
#  'Dunaegyháza': 1504,
#  'Dunafalva': 818,
#  'Dunaföldvár': 8666,
#  'Dunaharaszti': 20260,
#  'Dunakeszi': 40334,
#  'Dunakiliti': 1857,
#  'Dunapataj': 3169,
#  'Dunaremete': 241,
#  'Dunaszeg': 2006,
#  'Dunaszekcső': 1932,
#  'Dunaszentbenedek': 812,
#  'Dunaszentgyörgy': 2520,
#  'Dunaszentmiklós': 465,
#  'Dunaszentpál': 739,
#  'Dunasziget': 1437,
#  'Dunatetétlen': 530,
#  'Dunaújváros': 48010,
#  'Dunavarsány': 7480,
#  'Dunavecse': 3937,
#  'Dusnok': 2873,
#  'Dúzs': 267,
#  'Ebergőc': 157,
#  'Ebes': 4390,
#  'Écs': 1809,
#  'Ecséd': 3193,
#  'Ecseg': 1217,
#  'Ecsegfalva': 1157,
#  'Ecseny': 219,
#  'Ecser': 3714,
#  'Edde': 192,
#  'Edelény': 10019,
#  'Edve': 106,
#  'Eger': 56166,
#  'Egerág': 970,
#  'Egeralja': 234,
#  'Egeraracsa': 300,
#  'Egerbakta': 1434,
#  'Egerbocs': 531,
#  'Egercsehi': 1377,
#  'Egerfarmos': 675,
#  'Egerlövő': 534,
#  'Egerszalók': 1886,
#  'Egerszólát': 1062,
#  'Égerszög': 43,
#  'Egervár': 1006,
#  'Egervölgy': 327,
#  'Egyed': 517,
#  'Egyek': 4895,
#  'Egyházasdengeleg': 467,
#  'Egyházasfalu': 838,
#  'Egyházasgerge': 718,
#  'Egyházasharaszti': 323,
#  'Egyházashetye': 322,
#  'Egyházashollós': 534,
#  'Egyházaskesző': 507,
#  'Egyházaskozár': 792,
#  'Egyházasrádóc': 1275,
#  'Elek': 4816,
#  'Ellend': 217,
#  'Előszállás': 2186,
#  'Emőd': 4895,
#  'Encs': 6201,
#  'Encsencs': 1960,
#  'Endrefalva': 1321,
#  'Endrőc': 353,
#  'Enese': 1785,
#  'Enying': 6768,
#  'Eperjes': 495,
#  'Eperjeske': 1149,
#  'Eplény': 523,
#  'Epöl': 592,
#  'Ercsi': 7999,
#  'Érd': 65277,
#  'Erdőbénye': 1018,
#  'Erdőhorváti': 545,
#  'Erdőkertes': 7772,
#  'Erdőkövesd': 640,
#  'Erdőkürt': 545,
#  'Erdősmárok': 89,
#  'Erdősmecske': 368,
#  'Erdőtarcsa': 492,
#  'Erdőtelek': 3174,
#  'Erk': 881,
#  'Érpatak': 1673,
#  'Érsekcsanád': 2828,
#  'Érsekhalma': 638,
#  'Érsekvadkert': 3497,
#  'Értény': 752,
#  'Erzsébet': 301,
#  'Esztár': 1366,
#  'Eszteregnye': 679,
#  'Esztergályhorváti': 450,
#  'Esztergom': 30434,
#  'Ete': 554,
#  'Etes': 1413,
#  'Etyek': 4402,
#  'Fábiánháza': 1617,
#  'Fábiánsebestyén': 2020,
#  'Fácánkert': 633,
#  'Fadd': 4317,
#  'Fáj': 365,
#  'Fajsz': 1658,
#  'Fancsal': 294,
#  'Farád': 1926,
#  'Farkasgyepű': 405,
#  'Farkaslyuk': 1759,
#  'Farmos': 3621,
#  'Fazekasboda': 203,
#  'Fedémes': 309,
#  'Fegyvernek': 6415,
#  'Fehérgyarmat': 7861,
#  'Fehértó': 448,
#  'Fehérvárcsurgó': 1971,
#  'Feked': 165,
#  'Feketeerdő': 563,
#  'Felcsút': 1831,
#  'Feldebrő': 1021,
#  'Felgyő': 1281,
#  'Felpéc': 847,
#  'Felsőberecki': 273,
#  'Felsőcsatár': 502,
#  'Felsődobsza': 882,
#  'Felsőegerszeg': 135,
#  'Felsőgagy': 170,
#  'Felsőjánosfa': 183,
#  'Felsőkelecsény': 364,
#  'Felsőlajos': 1012,
#  'Felsőmarác': 261,
#  'Felsőmocsolád': 423,
#  'Felsőnána': 577,
#  'Felsőnyárád': 980,
#  'Felsőnyék': 1019,
#  'Felsőörs': 1631,
#  'Felsőpáhok': 640,
#  'Felsőpakony': 3443,
#  'Felsőpetény': 628,
#  'Felsőrajk': 725,
#  'Felsőregmec': 322,
#  'Felsőszenterzsébet': 14,
#  'Felsőszentiván': 1928,
#  'Felsőszentmárton': 881,
#  'Felsőszölnök': 556,
#  'Felsőtárkány': 3358,
#  'Felsőtelekes': 683,
#  'Felsőtold': 142,
#  'Felsővadász': 543,
#  'Felsőzsolca': 6750,
#  'Fényeslitke': 2350,
#  'Fenyőfő': 107,
#  'Ferencszállás': 615,
#  'Fertőboz': 258,
#  'Fertőd': 3461,
#  'Fertőendréd': 589,
#  'Fertőhomok': 638,
#  'Fertőrákos': 2144,
#  'Fertőszentmiklós': 3891,
#  'Fertőszéplak': 1318,
#  'Fiad': 155,
#  'Filkeháza': 97,
#  'Fityeház': 651,
#  'Foktő': 1606,
#  'Folyás': 328,
#  'Fonó': 293,
#  'Fony': 343,
#  'Fonyód': 4728,
#  'Forráskút': 2336,
#  'Forró': 2432,
#  'Fót': 18968,
#  'Földeák': 3025,
#  'Földes': 3998,
#  'Főnyed': 76,
#  'Fulókércs': 398,
#  'Furta': 1136,
#  'Füle': 834,
#  'Fülesd': 446,
#  'Fülöp': 1738,
#  'Fülöpháza': 822,
#  'Fülöpjakab': 1147,
#  'Fülöpszállás': 2278,
#  'Fülpösdaróc': 318,
#  'Fürged': 666,
#  'Füzér': 467,
#  'Füzérkajata': 110,
#  'Füzérkomlós': 331,
#  'Füzérradvány': 318,
#  'Füzesabony': 7781,
#  'Füzesgyarmat': 5665,
#  'Fűzvölgy': 143,
#  'Gáborján': 876,
#  'Gáborjánháza': 66,
#  'Gacsály': 893,
#  'Gadács': 73,
#  'Gadány': 367,
#  'Gadna': 262,
#  'Gádoros': 3555,
#  'Gagyapáti': 16,
#  'Gagybátor': 226,
#  'Gagyvendégi': 200,
#  'Galambok': 1292,
#  'Galgaguta': 579,
#  'Galgagyörk': 1046,
#  'Galgahévíz': 2495,
#  'Galgamácsa': 1957,
#  'Gálosfa': 255,
#  'Galvács': 91,
#  'Gamás': 722,
#  'Ganna': 243,
#  'Gánt': 847,
#  'Gara': 2457,
#  'Garáb': 54,
#  'Garabonc': 716,
#  'Garadna': 432,
#  'Garbolc': 152,
#  'Gárdony': 9927,
#  'Garé': 295,
#  'Gasztony': 439,
#  'Gátér': 966,
#  'Gávavencsellő': 3352,
#  'Géberjén': 526,
#  'Gecse': 396,
#  'Géderlak': 983,
#  'Gégény': 1918,
#  'Gelej': 588,
#  'Gelénes': 509,
#  'Gellénháza': 1540,
#  'Gelse': 1056,
#  'Gelsesziget': 280,
#  'Gemzse': 860,
#  'Gencsapáti': 2869,
#  'Gérce': 1087,
#  'Gerde': 520,
#  'Gerendás': 1311,
#  'Gerényes': 256,
#  'Geresdlak': 771,
#  'Gerjen': 1199,
#  'Gersekarát': 633,
#  'Geszt': 754,
#  'Gesztely': 2798,
#  'Geszteréd': 1634,
#  'Gétye': 122,
#  'Gibárt': 374,
#  'Gic': 427,
#  'Gige': 344,
#  'Gilvánfa': 369,
#  'Girincs': 917,
#  'Gógánfa': 751,
#  'Golop': 523,
#  'Gomba': 2972,
#  'Gombosszeg': 42,
#  'Gór': 307,
#  'Gordisa': 314,
#  'Gosztola': 44,
#  'Göd': 18565,
#  'Gödöllő': 34172,
#  'Gödre': 831,
#  'Gölle': 937,
#  'Gömörszőlős': 77,
#  'Gönc': 1951,
#  'Göncruszka': 623,
#  'Gönyű': 3135,
#  'Görbeháza': 2402,
#  'Görcsöny': 1663,
#  'Görcsönydoboka': 387,
#  'Görgeteg': 1157,
#  'Gősfa': 340,
#  'Grábóc': 180,
#  'Gulács': 795,
#  'Gutorfölde': 1021,
#  'Gyál': 23486,
#  'Gyalóka': 63,
#  'Gyanógeregye': 153,
#  'Gyarmat': 1204,
#  'Gyékényes': 948,
#  'Gyenesdiás': 3720,
#  'Gyepükaján': 329,
#  'Gyermely': 1450,
#  'Gyód': 672,
#  'Gyomaendrőd': 13674,
#  'Gyóró': 419,
#  'Gyömöre': 1254,
#  'Gyömrő': 16670,
#  'Gyöngyfa': 156,
#  'Gyöngyös': 32385,
#  'Gyöngyösfalu': 1083,
#  'Gyöngyöshalász': 2531,
#  'Gyöngyösmellék': 283,
#  'Gyöngyösoroszi': 1518,
#  'Gyöngyöspata': 2472,
#  'Gyöngyössolymos': 2972,
#  'Gyöngyöstarján': 2460,
#  'Gyönk': 2066,
#  'Győr': 131564,
#  'Győrasszonyfa': 494,
#  'Györe': 668,
#  'Györgytarló': 563,
#  'Györköny': 938,
#  'Győrladamér': 1623,
#  'Győröcske': 118,
#  'Győrság': 1478,
#  'Győrsövényház': 746,
#  'Győrszemere': 3209,
#  'Győrtelek': 1580,
#  'Győrújbarát': 6233,
#  'Győrújfalu': 1575,
#  'Győrvár': 606,
#  'Győrzámoly': 2581,
#  'Gyugy': 275,
#  'Gyula': 31679,
#  'Gyulaháza': 1869,
#  'Gyulaj': 977,
#  'Gyulakeszi': 695,
#  'Gyúró': 1254,
#  'Gyügye': 234,
#  'Gyüre': 1200,
#  'Gyűrűs': 88,
#  'Hács': 384,
#  'Hagyárosbörönd': 305,
#  'Hahót': 1055,
#  'Hajdúbagos': 1972,
#  'Hajdúböszörmény': 31306,
#  'Hajdúdorog': 8888,
#  'Hajdúhadház': 12458,
#  'Hajdúnánás': 16975,
#  'Hajdúsámson': 13105,
#  'Hajdúszoboszló': 23309,
#  'Hajdúszovát': 3038,
#  'Hajmás': 246,
#  'Hajmáskér': 3064,
#  'Hajós': 3134,
#  'Halastó': 91,
#  'Halászi': 2973,
#  'Halásztelek': 9310,
#  'Halimba': 1097,
#  'Halmaj': 1853,
#  'Halmajugra': 1196,
#  'Halogy': 235,
#  'Hangács': 573,
#  'Hangony': 1480,
#  'Hantos': 910,
#  'Harasztifalu': 146,
#  'Harc': 901,
#  'Harka': 1919,
#  'Harkakötöny': 934,
#  'Harkány': 4065,
#  'Háromfa': 756,
#  'Háromhuta': 125,
#  'Harsány': 2014,
#  'Hárskút': 653,
#  'Harta': 3275,
#  'Hásságy': 248,
#  ...}

# %% [markdown]
# # Create commuting.json

# %%
edges = {}
mtx = np.zeros((N,N))
for _,row in KSH.iterrows():
    weight = row["CommutersAll"]
    orig,dest = row["origName"], row["destName"]
    if((orig in cities) and (dest in cities)):
        edges[(place_id_dict[orig], place_id_dict[dest])] = weight/pop_dict[orig]
        mtx[place_id_dict[orig], place_id_dict[dest]] = weight/pop_dict[orig]

# %%
print(f"#of edges: {len(edges)} [{N**2}] ==> {100*len(edges)/N**2:.3f}% density")
# Out:
# #of edges: 10502 [28224] ==> 37.209% density

# %%
network = []
for i in range(N):
    for j in range(N):
        if(i==j): continue
        network.append({"from":i, "to":j, "weight":mtx[i,j]})

commuting = {
    "N":N,
    "network":network
}

# %%
len(network)
# Out:
# 28056

# %%
with open("../input/hun/commuting_KSH.json", "w") as f:
    f.write(json.dumps(commuting))

# %% [markdown]
# # Create the config.json

# %%
d = {
  "commuting_file": "commuting_KSH.json",
  "populations_file": "populations_KSH.json",
  "contacts_file_home": "contacts_home.json",
  "contacts_file_other": "contacts_other.json",
  "Npop":f"{len(cities)}"}

with open("../input/hun/config.json", "w") as f:
    f.write(json.dumps(d, indent=4))

# %% [markdown]
# # Results

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
real_data = pd.read_csv("../../data/hun/hun_infected.csv", sep=',')
real_data=real_data.rename(columns={
    "Dátum": "date",
    "Az új fertőzöttek számának napi alakulása Magyarországon": "I",
    "Hétnapos mozgóátlag":"avg"})[181:181+190].reset_index()
real_data
# Out:
#      index        date       I             avg
# 0      181  2020-09-01   118.0    148,85714286
# 1      182  2020-09-02   365.0    190,57142857
# 2      183  2020-09-03   301.0    220,57142857
# 3      184  2020-09-04   459.0    267,28571429
# 4      185  2020-09-05   510.0    317,57142857
# ..     ...         ...     ...             ...
# 185    366  2021-03-05  6369.0  4 766,42857143
# 186    367  2021-03-06  7269.0  5 098,00000000
# 187    368  2021-03-07  6201.0  5 345,42857143
# 188    369  2021-03-08  2696.0  5 112,57142857
# 189    370  2021-03-09  6494.0  5 645,42857143
#
# [190 rows x 4 columns]

# %%
def read_df(filename):
    df = pd.read_csv(filename, sep=',')
    inf_cols = [c for c in df.columns if c[0]=='I']
    Is = df.filter(inf_cols, axis=1)
    #N = sum(pop_dict.values())
    return Is

def get_inf_curve(filename):
    sim = read_df(filename)
    return sim.sum(axis=1)

# %%
sim0 = read_df("../output/results.txt")
sim1 = read_df("../output/results.txt")
#sim1 = read_df("../output/sim/sim1.txt")

# %%
plt.figure(figsize=(12, 10))
plt.plot(sim0.sum(axis=1)*(0.015), label="Sim0")
plt.plot(sim1.sum(axis=1)*0.015, label="Sim1")
plt.plot(real_data["I"], label="Real")
plt.legend()
plt.title("Simalation vs real data")
# Out:
# Text(0.5, 1.0, 'Simalation vs real data')

# %%
165*16*10
# Out:
# 26400

# %% [markdown]
# # All togeather

# %%
base_args = {
    "--config": "../input/hun",
    "--out": "../output/sim/temp.txt",
    "--maxT": "150"
}

global_args = {
    "procnum": 20,
}

# %%
import os
import copy
import numpy as np
import pandas as pd
import multiprocessing
import matplotlib.pyplot as plt
from subprocess import Popen, STDOUT, PIPE

def run(args, job_count, lock):
    # Run
    str_args = [str(item) for pair in args.items() for item in pair]
    #print(" ".join([ "../bin/main"] + str_args))
    p = Popen([ "../bin/main"] + str_args,
          stdout=PIPE, stdin=PIPE, stderr=STDOUT, bufsize=1, universal_newlines=True)

    out,err = p.communicate()
    #print(out)
    
    # Alert master, if ready
    with lock:
        job_count[0]+=1
        print('\r {}/{}'.format(job_count[0], job_count[1]), end='', flush=True)

    return 0

def measure(meas_name, arg_name, arg_space):
    # Init pool
    pool = multiprocessing.Pool(processes=global_args["procnum"])
    manager = multiprocessing.Manager()
    lock = manager.Lock()
    job_count = manager.Array("i", [0,len(arg_space)])
    
    os.makedirs(f"../output/{meas_name}", exist_ok=True)
    
    # Run async
    sims = {}
    for i,x in enumerate(arg_space):
        if type(x)==str:
            pass
        else:
            x = np.round_(x, decimals=4)
        args = copy.copy(base_args)
        args["--out"]=f"../output/{meas_name}/{i}.txt"
        args[arg_name]=f"{x}"
        #sims[(x,args["--out"])] = None
        sims[(x,args["--out"])] = pool.apply_async(run, args =(args, job_count, lock))
    
    # Collect async
    for k,v in sims.items():
        v.get()
    
    pool.close()
    pool.join()
    
    return sims.keys()

def get_inf_curve(filename):
    df = pd.read_csv(filename, sep=',')
    inf_cols = [c for c in df.columns if c[0]=='I']
    Is = df.filter(inf_cols, axis=1)
    return Is.sum(axis=1)

# %% [markdown]
# # Changing $R_0$

# %%
base_args = {
    "--config": "../input/hun",
    "--out": "../output/sim/temp.txt",
    "--maxT": "150",
}

# %%
sims_R0 = measure("R0", "--R0", np.linspace(1.0, 2.0, 20))

# %%
plt.figure(figsize=(12,10))
for val,file in sims_R0:
    if(val < 1.5 and val > 1.2):
        plt.plot(get_inf_curve(file), label=f"R0={val}")
plt.plot(real_data["I"]*25, label="Real")
plt.legend()
plt.show()

# %% [markdown]
# # Increasing $\beta$ after 50 days (by the factor $r_2$)

# %%
base_args = {
    "--config": "../input/hun",
    "--out": "../output/sim/temp.txt",
    "--maxT": "150",
    "--moving_t": "50",
    "--R0": "1.3158",
}

# %%
sims_r2 = measure("r2", "--r2", np.linspace(1.0, 2.0, 20))

# %%
plt.figure(figsize=(12,10))
for val,file in sims_r2:
    plt.plot(get_inf_curve(file), label=f"r2={val}")
plt.plot(real_data["I"]*5, label="Real")
plt.legend()
plt.show()

# %% [markdown]
# # Adding seasonality ($c$)
#
# $$ seasonality =  0.5 \cdot c \cdot \cos \left( \frac{2 \pi t}{366} \right) + (1-0.5 \cdot c ) $$

# %%
def f(c,t, cut ):
    return np.maximum(0.5*c*np.cos(2*np.pi*t/366.0)+(1-0.5*c), 1-c*cut)

x = np.linspace(0,366, 366)

plt.figure(figsize=(12,10))
for c in np.linspace(0,1,10):
    y = f(c, x, cut = 1.0)
    plt.plot(x,y, label=f"{c}")
plt.xlabel('Scale')
plt.ylabel('Days')
plt.legend()

plt.figure(figsize=(12,10))
for c in np.linspace(0,1,10):
    y = f(c, x, cut = 0.8)
    plt.plot(x,y, label=f"{c}")
plt.xlabel('Scale')
plt.ylabel('Days')
plt.legend()

# %%
sims = measure("c2", "--c", np.linspace(0.0, 1.0, 20))
# Out:
#  20/20

# %%
plt.figure(figsize=(12,10))
plt.plot(real_data["I"]*5, label="Real")

for val,file in sims:
    if(val < 0.3):
        plt.plot(get_inf_curve(file), label=f"c={val}")
plt.legend()

# %%
base_args = {
    "--config": "../input/hun",
    "--out": "../output/sim/temp.txt",
    "--maxT": "150",
    "--moving_t": "50",
    "--R0": "2.6",
}

# %%
sims = measure("c3", "--c", np.linspace(0.0, 1.0, 20))
# Out:
#  20/20

# %%
plt.figure(figsize=(12,10))
plt.plot(real_data["I"]*10, label="Real")

for val,file in sims:
    plt.plot(get_inf_curve(file), label=f"c={val}")
plt.legend()

# %% [markdown]
# # Changing the contact mtx

# %%
base_args = {
    "--config": "../input/hun",
    "--out": "../output/sim/temp.txt",
    "--maxT": "150",
    "--R0": "2.6",
}

# %%
sims_contact = measure("contact_mtx", "--contact_mtx",
                       ["contacts_other.json", "contacts_other0.json", "contacts_other1.json",
                        "contacts_other2.json", "contacts_other3.json", "contacts_other4.json"])
# Out:
#  6/6

# %%
plt.figure(figsize=(12,10))
for val,file in sims_contact:
    plt.plot(get_inf_curve(file)[:60], label=f"contact={val}")
#plt.plot(real_data["I"]*10, label="Real")
plt.legend()
plt.show()

# %%
base_args = {
    "--config": "../input/hun",
    "--out": "../output/sim/temp.txt",
    "--maxT": "150",
    "--R0": "2.0",
}

# %%
sims_contact2 = measure("contact_mtx", "--contact_mtx",
                       ["contacts_other.json", "contacts_other0.json", "contacts_other1.json",
                        "contacts_other2.json", "contacts_other3.json", "contacts_other4.json"])
# Out:
#  6/6

# %%
plt.figure(figsize=(12,10))
for val,file in sims_contact2:
    plt.plot(get_inf_curve(file)[:60], label=f"contact={val}")
#plt.plot(real_data["I"]*10, label="Real")
plt.legend()
plt.show()

# %%
base_args = {
    "--config": "../input/hun",
    "--out": "../output/sim/temp.txt",
    "--maxT": "150",
    "--moving_t": "50",
    "--R0": "1.3158",
}

# %%
sims = measure("c", "--c", np.linspace(0.0, 1.0, 20))

# %%
for val,file in sims:
    plt.plot(get_inf_curve(file), label=f"c={val}")
plt.plot(real_data["I"]*12, label="Real")
plt.legend()

# %%
sims = measure("R0", "--R0", np.linspace(1.0, 2.0, 20))

# %%
for val,file in sims:
    if(val < 1.5 and val > 1.2):
        #print(val,'\n', get_inf_curve(file))
        plt.plot(get_inf_curve(file), label=f"R0={val}")
plt.plot(real_data["I"]*25, label="Real")
plt.legend()

# %%
for val,file in sims:
    plt.plot(get_inf_curve(file), label=f"R0={val}")
plt.plot(real_data["I"]*25, label="Real")
plt.legend()

# %%
df = pd.read_csv("../output/R0/10.txt", sep=',')
for i in range(29, 47):
    inf_cols = [c for c in df.columns if c[0:4]==f'I_{i}']
    Is = df.filter(inf_cols, axis=1)
    plt.plot(Is.sum(axis=1), label=f"{i}")

plt.legend()

# %%
sims = measure("r1", "--r1", np.linspace(0.6, 1.0, 20))
# Out:
#  20/20

# %%
for val,file in sims:
    #print(val,'\n', get_inf_curve(file))
    plt.plot(get_inf_curve(file), label=f"r1={val}")
plt.legend()
# Out:
# 0.6
#  0       9996
# 1      10143
# 2      10408
# 3      10731
# 4      11024
#        ...
# 145     2021
# 146     1899
# 147     1729
# 148     1609
# 149     1513
# Length: 150, dtype: int64
# 0.6211
#  0       9891
# 1      10078
# 2      10279
# 3      10688
# 4      11034
#        ...
# 145     1299
# 146     1181
# 147     1155
# 148     1095
# 149      974
# Length: 150, dtype: int64
# 0.6421
#  0       9944
# 1      10183
# 2      10508
# 3      10817
# 4      11318
#        ...
# 145      745
# 146      671
# 147      602
# 148      542
# 149      504
# Length: 150, dtype: int64
# 0.6632
#  0       9926
# 1      10109
# 2      10604
# 3      11023
# 4      11557
#        ...
# 145      390
# 146      356
# 147      325
# 148      297
# 149      284
# Length: 150, dtype: int64
# 0.6842
#  0      10041
# 1      10296
# 2      10710
# 3      11394
# 4      11938
#        ...
# 145      292
# 146      265
# 147      247
# 148      217
# 149      211
# Length: 150, dtype: int64
# 0.7053
#  0       9974
# 1      10387
# 2      10934
# 3      11488
# 4      12221
#        ...
# 145      111
# 146       97
# 147       84
# 148       75
# 149       72
# Length: 150, dtype: int64
# 0.7263
#  0       9926
# 1      10402
# 2      11257
# 3      11659
# 4      12381
#        ...
# 145       67
# 146       57
# 147       50
# 148       46
# 149       45
# Length: 150, dtype: int64
# 0.7474
#  0       9895
# 1      10393
# 2      11001
# 3      11637
# 4      12476
#        ...
# 145       41
# 146       34
# 147       32
# 148       28
# 149       30
# Length: 150, dtype: int64
# 0.7684
#  0      10024
# 1      10417
# 2      11088
# 3      11831
# 4      12823
#        ...
# 145       23
# 146       17
# 147       15
# 148       10
# 149       10
# Length: 150, dtype: int64
# 0.7895
#  0       9961
# 1      10581
# 2      11302
# 3      12149
# 4      13062
#        ...
# 145       18
# 146       14
# 147       13
# 148       10
# 149       14
# Length: 150, dtype: int64
# 0.8105
#  0      10026
# 1      10482
# 2      11313
# 3      12009
# 4      13100
#        ...
# 145        4
# 146        4
# 147        2
# 148        2
# 149        0
# Length: 150, dtype: int64
# 0.8316
#  0      10021
# 1      10647
# 2      11527
# 3      12204
# 4      13600
#        ...
# 145        7
# 146        4
# 147        6
# 148        3
# 149        2
# Length: 150, dtype: int64
# 0.8526
#  0      10039
# 1      10654
# 2      11593
# 3      12610
# 4      13939
#        ...
# 145        3
# 146        1
# 147        1
# 148        2
# 149        1
# Length: 150, dtype: int64
# 0.8737
#  0      10013
# 1      10561
# 2      11610
# 3      12825
# 4      14098
#        ...
# 145        4
# 146        5
# 147        3
# 148        4
# 149        0
# Length: 150, dtype: int64
# 0.8947
#  0       9893
# 1      10622
# 2      11504
# 3      12746
# 4      14146
#        ...
# 145        0
# 146        0
# 147        0
# 148        0
# 149        0
# Length: 150, dtype: int64
# 0.9158
#  0      10061
# 1      10729
# 2      11743
# 3      13011
# 4      14703
#        ...
# 145        2
# 146        3
# 147        1
# 148        1
# 149        0
# Length: 150, dtype: int64
# 0.9368
#  0      10091
# 1      10780
# 2      11937
# 3      13337
# 4      15021
#        ...
# 145        2
# 146        1
# 147        1
# 148        0
# 149        0
# Length: 150, dtype: int64
# 0.9579
#  0       9960
# 1      10812
# 2      11832
# 3      13302
# 4      14969
#        ...
# 145        0
# 146        0
# 147        0
# 148        0
# 149        0
# Length: 150, dtype: int64
# 0.9789
#  0       9981
# 1      10788
# 2      12106
# 3      13431
# 4      15257
#        ...
# 145        0
# 146        0
# 147        0
# 148        0
# 149        0
# Length: 150, dtype: int64
# 1.0
#  0       9903
# 1      10748
# 2      12025
# 3      13451
# 4      15641
#        ...
# 145        0
# 146        0
# 147        0
# 148        0
# 149        0
# Length: 150, dtype: int64
